# %%
# !pip install streamlit_jupyter
# Out:
# ...
#      ---------------------------------------- 8.4/8.4 MB 18.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 67.6/67.6 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 123.4/123.4 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 33.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 195.4/195.4 kB 12.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 996.9/996.9 kB 65.8 MB/s eta 0:00:00
# ...
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# ...
#      ---------------------------------------- 240.6/240.6 kB ? eta 0:00:00
# ...
#      --------------------------------------- 24.9/24.9 MB 32.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 36.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 87.5/87.5 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import streamlit as st 
st.title("Example")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9388\2989871048.py in <module>
# ----> 1 st.title("Example")
#
# NameError: name 'st' is not defined
